# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Line Chart

# %%
yield_apples = [.895, .91, .919, .926, .929, .931]

# %%
plt.plot(yield_apples);      ## x axis indexes are the index numbers of the list's corresponding values

# %% [markdown]
# Line Chart - Customizing X - Axis

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [.895, .91, .919, .926, .929, .931]

# %%
plt.plot(years, yield_apples)

# %% [markdown]
# Axis Labels

# %%
plt.plot(years, yield_apples)
plt.xlabel("Year")
plt.ylabel("Yield (tons per hectare)");

# %% [markdown]
# Plotting Multiple Lines

# %%
years = range(2000,2012)
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896]
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
plt.plot(years , oranges)
plt.plot(years, apples)
plt.xlabel("Years")
plt.ylabel("Yield (tons per hectare)");

# %% [markdown]
# Chart Title and Legend and, Line Markers

# %%
plt.plot(years, apples, marker = 'o')
plt.plot(years, oranges, marker = '*')
plt.xlabel("Years")
plt.ylabel("Yields (tons per hectare)")
plt.title("Crop Yields in particular region")
plt.legend(["Apples","Oranges"])

# %% [markdown]
# Figure Size

# %%
plt.plot(years, oranges)
plt.figure(figsize = (20,10))

# %% [markdown]
# The fmt argument provides a shorthand for specifying the marker shape, line style, and line color. It can be provided as the third argument to plt.plot.
#
# fmt = '[marker][line][color]'

# %%
plt.plot(years, oranges, 'or')
plt.title("Yield of Oranges (tons per hectare)");

# %%
import matplotlib
matplotlib.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
# ...

# %% [markdown]
# Bar chart

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]
plt.bar(years, oranges);
plt.title("Years vs Oranges");

# %% [markdown]
# We can stack bars on top of one another. We use the bottom argument of plt.bar to achieve this

# %%
plt.bar(years, apples)
plt.bar(years, oranges, bottom = apples);
plt.title("Years vs  Oranges + Apples");
